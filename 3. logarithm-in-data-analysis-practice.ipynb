# %% [markdown]
# # Logarithm in Data Analysis, Practice

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df = pd.read_csv('/kaggle/input/practice-logarithm-in-data-analysis/revenue.csv')

# %%
df
# Out:
#          company  revenue
# 0         Tesla      31.0
# 1           UBER     11.0
# 2         Amazon    386.0
# 3  Jindal  Steel      4.7
# 4      Axis Bank      5.6
# 5        Vedanta     11.3

# %%
# Making a bar chart

df.plot(x='company', y='revenue', kind = 'bar')
# Out:
# <Axes: xlabel='company'>

# %%
# Making a bar chart using log

df.plot(x='company', y='revenue', kind = 'bar', logy=True)
# Out:
# <Axes: xlabel='company'>
